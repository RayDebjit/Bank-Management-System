# %%
### FORMAT FOR INFROMATION DETAILS
###  NAME  DOB  Age  ACC.NO  EMAIL-ID  ADD  PSSD  AMT

# %%
import pickle as t
import smtplib
import getpass
import os

# %%
fil = []

# %%
# information regarding education loan in bank using file handling

# %%
#with open('bankinfo.txt') as f:
#  contents= f.read()
#  print(contents)

# %%
#with open('customer info.txt') as f:
#  contents= f.read()
#  print(contents)

# %%
semail = "bed.deb2003@gmail.com"
npassword = getpass.getpass("get psd:")
# Out:
# get psd:··········

# %%
def sending_mail(to_address,subject,message):
    smtp_object =smtplib.SMTP('smtp.gmail.com',587)
    smtp_object.ehlo()
    smtp_object.starttls()
    smtp_object.login(semail,npassword)
    ## subject = "jhwg"
    ## message = "uie"
    msg = "Subject: " + subject + '\n' + message
    smtp_object.sendmail(semail,to_address,msg)
    smtp_object.quit()

# %%
### for administrative purpose
def clients(fil):
  for i in fil:
    q = open(i,"rb")
    k = t.load(q)
    print(k)
    q.close() 

def delfile(nam):
  return os.remove(nam+".txt")

# %%
###  OOP 

class acc_holder:
  
  def __init__(self,nam):
    self.userid = nam
    fl_name = self.userid+".txt"
    p = open(fl_name,"rb")
    k = t.load(p)
    self.name = k[0]
    self.balance = k[7]
    self.acc_no = k[3]
    self.pssd = k[6]
    self.email = k[4]
    p.close()

  def __str__(self):
    print("WELCOME {} !!".format(self.name))
    return " We are happy to be our client. Here you can get all the services we provide "

  def withdrawl(self,n):
    self.balance = self.balance - n
    print(" Withdrawl succesful !!! ")
    print("Current BALANCE is {}".format(self.balance))

  def deposit(self,n):
    self.balance = self.balance + n
    print(" Deposit succesful !!! ")
    print(" Current BALANCE is {} ".format(self.balance))

  def details(self):
    fl_name = self.userid+".txt"
    p = open(fl_name,"rb")
    k = t.load(p)
    print("Name : {}".format(k[0]))
    print("DOB : {}".format(k[1]))
    print("Age : {}".format(k[2]))
    print("Acc.No : {}".format(k[3]))
    print("Email - Id : {}".format(k[4]))
    print("Address : {}".format(k[5]))
    cl = input("do you want your password to be displayed ? (y/n)  :")
    if cl == "y":
      print("Password : {}".format(k[6]))
      p.close()
    else:
      p.close()
  
  def Loan(self):
    print("Citizens in India show that the Indian Nation Loan Scholarship Scheme which operated from 1963 would make") 
    print("the extra waste on expenditure for the reason of 'limiting', which means only the people who really need to borrow") 
    print("would apply the student loan for the future education. Because of this, most Indian students would be more careful \n to choose their jobs in order to pay back the balance due. ")
    
    print("The Indian government has launched a portal, Vidya Lakshmi, for students seeking educational loans and five banks including SBI,") 
    print("IDBI Bank and Bank of India have integrated their system with the portal. Vidya Lakshmi was launched on the occasion of Independence Day") 
    print("i.e. 15 August 2015 for the benefit of students seeking educational loans. Vidya Lakshmi was developed under three departments of India ")
    print("i.e. Department of Financial Services, Department of Higher Education and Indian Banks Association (IBA). Vidya Lakshmi Portal has been ") 
    print("developed under the Pradhan Mantri Vidya Lakshmi Karyakram and announced by the Honorable Finance Minister Shri Arun Jaitley in the budget") 
    print("speech of FY 2015-16. As on August 15, 2020 , 37 banks have registered on the Vidya Lakshmi Portal and offering 137 loan schemes. ")
    
    print("To bridge the constraint of increasing institutional fees, NSDL e-Governance in India launched Vidyasaarathi portal to help students seeking ")
    print("scholarship for studies in India or overseas.")
    print("Scope:")
    print(" The education loan is expected to grow at a rate of 32.3 per cent in 2009-10 and ")
    print("- At 39.8 per cent each in 2010-11and 2011-12 and ")
    print("- 44.8 per cent during the period 2012-13 to 2014-15. ")
    print("- Outward remittances for overseas education in the year ending March 2013 was $114 million[12]")

# %%
###  function for updating details

def update(a,loc,w):
  ###  NAME  DOB  Age  ACC.NO  EMAIL-ID  ADD  PSSD  AMT
  
  if a == 1:
    pname = input("Enter your new name :")
    w[0] = pname
    p.seek(loc,0)
    t.dump(w,p)
    print(w)
  elif a == 2:
    pdob = int(input("enter your dob :"))
    w[1] = pdob
    p.seek(loc,1)
    t.dump(w,p)
  elif a == 3:
    page = int(input("enter your age :"))
    w[2] = page
    p.seek(loc,2)
    t.dump(w,p)
  elif a == 4:
    pemail = input("Enter the email id :")
    w[4] = pemail
    p.seek(loc,4)
    t.dump(w,p)
  elif a == 5:
    padd = input("Enter the new add :")
    w[5] = padd
    p.seek(loc,5)
    t.dump(w,p)
  elif a == 6:
    ppsd = input("Enter the new password")
    w[6] = ppsd
    p.seek(loc,6)
    t.dump(w,p)
  else:
    pass

# %%
###  defining log_in fuctions

def log_in(nam):
  #nam = input("Enter your name :")
  for i in range(0,4):
      
      if i == 3:
        print("Intruder Alert !!!")
        print("This Account has been locked for 2 Days... ")
        print("To take immediate action please visit the nearest branch")
        print()
        print("Or Call to Customer Care services ")
        break
      else:
        passd = getpass.getpass("Enter your Password :")
        user = acc_holder(nam)
        if passd == user.pssd:
          print(user)
          print()  
          operation(nam)
          break
        else:
          print("Sorry wrong details 😕 try again !!!")

# %%
## funtion for operation
def operation(nam):
  t = "yes"
  while t ==  "yes" :
    print(" a) ACCOUNT DETAILS ")
    print(" b) CHECK BALANCE ")
    print(" c) LOAN ")
    print(" d) MONEY TRANSFER ")
    print(" e) DEPOSIT ")
    print(" f) WITHDRAWL ")
    print(" g) CHANGE IN USER INFORMATION ")
    print(" h) DELETE ACCOUNT")
    
    m = input("Enter your Choice : ")                      # user will put their choice
    user = acc_holder(nam)

    if m == "a":
      user.details()
      t = input("Do you want to continue ? (yes/no) :")     ### more coding will be typed
    elif m == "b":
      print("Your Current Balance is {}".format(user.balance))
      t = input("Do you want to continue ? (yes/no) :")
    elif m == "c":
      user.Loan()
      t = input("Do you want to continue ? (yes/no) :")     ### more coding will be typed
    elif m == "d":
      acc_no = int(input("Receiver's Account No :"))
      acc_name = input("Receiver's Name :")        
      am = int(input("Enter the amount to be transfer :"))
      user1 = acc_holder(acc_name)
      user.withdrawl(am)
      user1.deposit(am)
      print("Transfer Successful !!! 😀")
      to_address = user1.email
      subject = "Money Transfer"
      message = "Respected Sir/Mam, \n The Transaction has been succesfull made with {} {} \n Thank you for banking with us \n\n Hope you are happy with our Services \n Regards \n SERA Bank".format(acc_name,acc_no)
      sending_mail(to_address,subject,message)
      t = input("Do you want to continue ? (yes/no) :")
    elif m == "e":
      dep_amt = int(input("Enter the amount you want to deposit :"))
      user.deposit(dep_amt)
      print("You have successfully deposited {} to your account !!!".format(user.balance))
      print("Now Your Bank Balance is {}".format(user.balance))
      t = input("Do you want to continue ? (yes/no) :")
    elif m == "f":
      wd_amt = int(input("Enter the amount you want to withdrawl :"))
      user.deposit(wd_amt)
      print("Withdrawn is successful !!! ")
      print("Now Your Bank Balance is {}".format(user.balance))
      t = input("Do you want to continue ? (yes/no) :")
    elif m == "g":                                               
      
      p = open(nam+".txt","rb+")
      loc = p.tell()
      w = t.load(p)
      print(w)
      
      print("What do you want to change ?")
      print("1. Name")
      print("2. DOB")
      print("3. Age")
      print("4. Email-Id")
      print("5. Address")
      print("6. Password")
      while j == "yes":
        f = int(input("Enter your choice (only no) :"))
        update(f,loc,w)
        j = input("do you want to continue ? (yes/no) :")

      else:
        print("We are happy to provide you service !!! 😊")
        p.close()

      t = input("Do you want to continue ? (yes/no) :")
    elif m == "h":
      delfile(user.userid)
      t = "no"
      print("Your account has been removed")

    else :
      print("Invalid Input !!!")
      print("Please select the valid option")
      t = input("Do you want to continue ? (yes/no) :")
  else:
    print("You just log out")

# %%
## function for opening file for new user

def new_file(abc,defg,dob,age,acc_no,email,add,pasd):
  name = abc + defg
  aname = abc+" "+defg
  fil_name = name+".txt"
  amt = 0
  p = open(fil_name,"wb")
  t.dump([aname,dob,age,acc_no,email,add,pasd,amt],p)
  print("Your UserId is {}".format(name))
  print("UserId will be used to log in")
  p.close()
  fil.append(fil_name)

# %%
### defining create account fucntion 
def name(fname,lname):
    print("WELCOME SIR/MADAM"+(" ") + fname +(" ")+ lname)

def ageis(age):
    if age < 18:
      print("account must be operated by elders !!!")
    else :
      pass
#def psd():
#  epsswd = input("Enter your password :")
#  print("Please reconfirm your password")
#  epsswd = input("Enter your password :")
#  return epsswd

#account_no = 20210
def create_acc():
  print("Please enter the following details")
  first_name = input("Enter your first name:\n")
  last_name = input("Enter your last name:\n")
  DOB = input("Enter your date of birth (DD-MM-YYYY) :")
  #accno = account_no
  account_no = 20210
  add = input("Enter your address :")
  email = input("Enter your email-id :")
  epsswd = input("Enter your password :")
  print("Please reconfirm your password")
  epsswd = input("Enter your password :")
  AGE = int(input("Enter your age :"))
  ageis(AGE)
  name(first_name,last_name)
  new_file(first_name,last_name,DOB,AGE,account_no,email,add,epsswd)
  subject = "Creating Account"
  message = "Respected {}, \n You have successfully created an account in SERA Bank. Below shown are the services we provide through online \n ALL MONEY TRANSACTIONS \n EDITING PERSONAL INFORMATION \n\n Hope you are happy with our Services \n Regards \n SERA Bank".format(first_name)
  sending_mail(email,subject,message)
  account_no +=1     
  var1 = input("do you want log in ? (y/n)")      ### yes, y, YES, "Yes"
  if var1 == "y":
    nam = input("Enter your userID :")
    log_in(nam)
  else:
    print("thank you !!!")

# %%
### defining invoice fuction
##  DICTIONARY

# %%
###  This is programme code for Bank Management ###

# %%
print("                                 *********** WELCOME TO SERA ***********                     ")
print("                        😀     Step into the world of benefits with SERA bank   😀      ")
print("                                                                                               ")
print("Single Investment today will give                                         Short way, long cherished dreams ")
print("   multiple benefits tomorrow                                      with speedy procssing and minimum paper work")
print(" ")
print("=====================================================================================================================")
print("         ")
print("          :: IMPORTANT INSTRUCTION REGARDING STANDING INSTRUCTION ON YOUR CREDIT AND DEBIT CARD ::   ")
print("  starting on January 1,2022 Auto debit payments for recurring transactions, non complaint with new regulatory")
print(" guidlines will not be honored on you SERA bank crdit or debit cards & payments will have to made directly on the")
print("    on the merchant/website app. To know more about how to view, approve/manage your recurring transaction")
print(" ")
print("  ")

print("  Customer Service is our 1st priority. With keeping that in mind below shown are few services we provide 👨‍⚖️ ")
print("  ")
print("             1. LOG IN                   ")
print("             2. CREATE ACCOUNT           ")

n = int(input("Enter your choice (only S.No) :"))
if n == 1:
  nam = input("Enter your userID :")
  log_in(nam)
elif n == 2:
  create_acc()
else:
  print("Thank you for Banking with us 😀")
# Out:
#                                  *********** WELCOME TO SERA ***********
#                         😀     Step into the world of benefits with SERA bank   😀
#
# Single Investment today will give                                         Short way, long cherished dreams
#    multiple benefits tomorrow                                      with speedy procssing and minimum paper work
#
# ...
#
#           :: IMPORTANT INSTRUCTION REGARDING STANDING INSTRUCTION ON YOUR CREDIT AND DEBIT CARD ::
#   starting on January 1,2022 Auto debit payments for recurring transactions, non complaint with new regulatory
#  guidlines will not be honored on you SERA bank crdit or debit cards & payments will have to made directly on the
#     on the merchant/website app. To know more about how to view, approve/manage your recurring transaction
#
#
#   Customer Service is our 1st priority. With keeping that in mind below shown are few services we provide 👨‍⚖️
#
#              1. LOG IN
# ...

# %%
#m = {"a": "account details","b":"money transfer"}

# %%
#print(m["a"])

# %%
#print(m["b"])

# %%
#pwd

# %%
#import pickle as t
#p = open("today.txt","wb")
#t.dump(['nikhil', '1996-08-24', 'nikhilsharma078@gmail.com', 202122100065, 2341],p)
#p.close()

# %%
p = open("DebjitRay.txt","rb")
print(t.load(p))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-a1dec7480b2e> in <module>()
# ----> 1 p = open("DebjitRay.txt","rb")
#       2 print(t.load(p))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'DebjitRay.txt'

# %%
delfile("DebjitRay")

# %%
#p.close()

# %%
p = open("DebjitRay.txt","rb+")
loc = p.tell()
k = t.load(p)
print(k)
k[1] = 19-10-2003
p.seek(loc,1)
t.dump(k,p)
print(k)

for x in k:
  print(x,end=", ")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-371f6944e4fa> in <module>()
# ----> 1 p = open("DebjitRay.txt","rb+")
#       2 loc = p.tell()
#       3 k = t.load(p)
#       4 print(k)
#       5 k[1] = 19-10-2003
#
# FileNotFoundError: [Errno 2] No such file or directory: 'DebjitRay.txt'

# %%
#p.close()

# %%
#b = "today"+".txt"
#p = open(b,"rb")
#k=t.load(p)
#print(k)

# %%
#c = str(200222)
#print(c)

# %%
#type(c)

# %%
#print("Name :{}".format(k[0]))
